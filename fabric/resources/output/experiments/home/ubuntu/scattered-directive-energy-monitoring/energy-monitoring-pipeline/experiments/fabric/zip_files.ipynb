# %% [markdown]
# # Zip files to download

# %% [markdown]
# This file serves to zip directories or delete them. UI doesn't allow multiple deletion nor download of folders.

# %%
import utils

# %%
utils.zip_directories_with_prefix("pa_baseline_event_driven")
# Out:
# > Found 8 matching folders:
#     - pa_baseline_event_driven_experiment_260708_0942
#     - pa_baseline_event_driven_experiment_260629_0633
#     - pa_baseline_event_driven_experiment_260708_0926
#     - pa_baseline_event_driven_experiment_260629_0420
#     - pa_baseline_event_driven_experiment_260629_0526
#     - pa_baseline_event_driven_experiment_260708_1105
#     - pa_baseline_event_driven_experiment_260708_1117
#     - pa_baseline_event_driven_experiment_260708_0957
#
# > Bundling into pa_baseline_event_driven_archive.zip...
# > Success! Created archive: pa_baseline_event_driven_archive.zip

# %% [markdown]
# # Clear directory

# %%
utils.clean_current_directory(["pa_baseline_event_driven"])
# Out:
# > Deleting all sub-folders inside:
#     /home/fabric/work/dynamos/output/experiments/home/ubuntu/scattered-directive-energy-monitoring/energy-monitoring-pipeline/experiments/fabric
# > Skipping directory pa_baseline_event_driven_experiment_260708_0942.
# > Skipping directory pa_baseline_event_driven_experiment_260629_0633.
# > Skipping directory pa_baseline_event_driven_experiment_260708_0926.
# > Skipping directory pa_baseline_event_driven_experiment_260629_0420.
# > Skipping directory pa_baseline_event_driven_experiment_260629_0526.
# > Skipping directory pa_baseline_event_driven_experiment_260708_1105.
# > Skipping directory pa_baseline_event_driven_archive.zip.
# > Skipping directory pa_baseline_event_driven_experiment_260708_1117.
# > Skipping directory pa_baseline_event_driven_experiment_260708_0957.
# > Done. Successfully deleted 69 files.
