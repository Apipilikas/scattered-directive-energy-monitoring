# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
from configuration import SLICE_NAME
from utils import upload_and_execute_file

fablib = fablib_manager()

fablib.show_config();
# Out:
# User: apipilikas@gmail.com bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_cab56 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_cab56 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_cab56 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_cab56_row0_col0, #T_cab56_row0_col1, #T_cab56_row1_col0, #T_cab56_row1_col1, #T_cab56_row2_col0, #T_cab56_row2_col1, #T_cab56_row3_col0, #T_cab56_row3_col1, #T_cab56_row4_col0, #T_cab56_row4_col1, #T_cab56_row5_col0, #T_cab56_row5_col1, #T_cab56_row6_col0, #T_cab56_row6_col1, #T_cab56_row7_col0, #T_cab56_row7_col1, #T_cab56_row8_col0, #T_cab56_row8_col1, #T_cab56_row9_col0, #T_cab56_row9_col1, #T_cab56_row10_col0, #T_cab56_row10_col1, #T_cab56_row11_col0, #T_cab56_row11_col1, #T_cab56_row12_col0, #T_cab56_row12_col1, #T_cab56_row13_col0, #T_cab56_row13_col1, #T_cab56_row14_col0, #T_cab56_row14_col1, #T_cab56_row15_col0, #T_cab56_row15_col1, #T_cab56_row16_col0, #T_cab56_row16_col1, #T_cab56_row17_col0, #T_cab56_row17_col1, #T_cab56_row18_col0, #T_cab56_row18_col1, #T_cab56_row19_col0, #T_cab56_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_cab56">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cab56_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_cab56_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_cab56_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_cab56_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_cab56_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_cab56_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_cab56_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_cab56_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_cab56_row7_col1" class="data row7 col1" >apipilikas_0000444352</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_cab56_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_cab56_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_cab56_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_cab56_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_cab56_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_cab56_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_cab56_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_cab56_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row16_col0" class="data row16 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_cab56_row16_col1" class="data row16 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row17_col0" class="data row17 col0" >Version</td>
#       <td id="T_cab56_row17_col1" class="data row17 col1" >1.9.3</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row18_col0" class="data row18 col0" >Data directory</td>
#       <td id="T_cab56_row18_col1" class="data row18 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_cab56_row19_col0" class="data row19 col0" >Project Name</td>
#       <td id="T_cab56_row19_col1" class="data row19 col1" >DYNAMOS project</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name=SLICE_NAME)

slice.delete()

# %%
# should fail although it seems that I need to run twice the previous cell 
slice = fablib.get_slice(name=SLICE_NAME)
slice.get_nodes()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # should fail although it seems that I need to run twice the previous cell
# ----> 2 slice = fablib.get_slice(name=SLICE_NAME)
#       3 slice.get_nodes()
#
# File /opt/conda/lib/python3.11/site-packages/fabrictestbed_extensions/fablib/fablib.py:2376, in FablibManager.get_slice(self, name, slice_id, user_only, show_un_submitted)
#    2374         return slices[0]
#    2375     else:
# -> 2376         raise Exception(
#    2377             f'Unable to find slice "{name}" for this project. Check slice name spelling and project id.'
#    2378         )
#    2379 else:
#    2380     raise Exception(
#    2381         "get_slice requires slice name (name) or slice id (slice_id)"
#    2382     )
#
# Exception: Unable to find slice "S-Drive-on-FABRIC" for this project. Check slice name spelling and project id.
